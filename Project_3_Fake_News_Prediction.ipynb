# %% [markdown]
# <a href="https://colab.research.google.com/github/MariemMhadhbii/-Machine_Learning_Projects/blob/main/Project_3_Fake_News_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# About the Dataset:
#
# 1. id: unique id for a news article
# 2. title: the title of a news article
# 3. author: author of the news article
# 4. text: the text of the article; could be incomplete
# 5. label: a label that marks whether the news article is real or fake:
#            1: Fake news
#            0: real News

# %% [markdown]
# Importing the Dependencies

# %%
import numpy as np
import pandas as pd
import re
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# printing the stopwords in English
print(stopwords.words('english'))
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 'she', "she'd", "she'll", "she's", 'should', 'shouldn', "shouldn't", "should've", 'so', 'some', 'such', 't', 'than', 'that', "that'll", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', "they'd", "they'll", "they're", "they've", 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 've', 'very', 'was', 'wasn', "wasn't", 'we', "we'd", "we'll", "we're", 'were', 'weren', "weren't", "we've", 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 'will', 'with', 'won', "won't", 'wouldn', "wouldn't", 'y', 'you', "you'd", "you'll", 'your', "you're", 'yours', 'yourself', 'yourselves', "you've"]

# %% [markdown]
# Data Pre-processing

# %%
# loading the dataset to a pandas DataFrame
news_dataset = pd.read_csv('/content/train.csv')

# %%
news_dataset.shape
# Out:
# (9900, 2)

# %%
# print the first 5 rows of the dataframe
news_dataset.head()
# Out:
#                                                 Text label
# 0   Top Trump Surrogate BRUTALLY Stabs Him In The...  Fake
# 1  U.S. conservative leader optimistic of common ...  Real
# 2  Trump proposes U.S. tax overhaul, stirs concer...  Real
# 3   Court Forces Ohio To Allow Millions Of Illega...  Fake
# 4  Democrats say Trump agrees to work on immigrat...  Real

# %%
# counting the number of missing values in the dataset
news_dataset.isnull().sum()
# Out:
# Text     0
# label    0
# dtype: int64

# %%
# replacing the null values with empty string
news_dataset = news_dataset.fillna('')

# %%
news_dataset['content'] = news_dataset['Text']

# %%
print(news_dataset.columns)
# Out:
# Index(['Text', 'label'], dtype='object')

# %%
print(news_dataset['content'])

# %%
# separating the data & label
X = news_dataset.drop(columns='label', axis=1)
Y = news_dataset['label']

# %%
print(X)
print(Y)
# Out:
#                                                    Text
# 0      Top Trump Surrogate BRUTALLY Stabs Him In The...
# 1     U.S. conservative leader optimistic of common ...
# 2     Trump proposes U.S. tax overhaul, stirs concer...
# 3      Court Forces Ohio To Allow Millions Of Illega...
# 4     Democrats say Trump agrees to work on immigrat...
# ...                                                 ...
# 9895   Wikileaks Admits To Screwing Up IMMENSELY Wit...
# 9896  Trump consults Republican senators on Fed chie...
# 9897  Trump lawyers say judge lacks jurisdiction for...
# 9898   WATCH: Right-Wing Pastor Falsely Credits Trum...
# 9899   Sean Spicer HILARIOUSLY Branded As Chickensh*...
#
# [9900 rows x 1 columns]
# 0       Fake
# 1       Real
# 2       Real
# 3       Fake
# 4       Real
#         ...
# 9895    Fake
# 9896    Real
# 9897    Real
# 9898    Fake
# 9899    Fake
# Name: label, Length: 9900, dtype: object

# %% [markdown]
# Stemming:
#
# Stemming is the process of reducing a word to its Root word
#
# example:
# actor, actress, acting --> act

# %%
port_stem = PorterStemmer()

# %%
def stemming(content):
    stemmed_content = re.sub('[^a-zA-Z]',' ',content)
    stemmed_content = stemmed_content.lower()
    stemmed_content = stemmed_content.split()
    stemmed_content = [port_stem.stem(word) for word in stemmed_content if not word in stopwords.words('english')]
    stemmed_content = ' '.join(stemmed_content)
    return stemmed_content

# %%
news_dataset['content'] = news_dataset['content'].apply(stemming)

# %%
news_dataset['content'] = news_dataset['Text']

# %%
news_dataset['content'] = news_dataset['content'].apply(stemming)

# %%
print(news_dataset['content'])
# Out:
# 0       top trump surrog brutal stab back pathet video...
# 1       u conserv leader optimist common ground health...
# 2       trump propos u tax overhaul stir concern defic...
# 3       court forc ohio allow million illeg purg voter...
# 4       democrat say trump agre work immigr bill wall ...
#                               ...
# 9895    wikileak admit screw immens twitter poll hilla...
# 9896    trump consult republican senat fed chief candi...
# 9897    trump lawyer say judg lack jurisdict defam law...
# 9898    watch right wing pastor fals credit trump save...
# 9899    sean spicer hilari brand chickensh bolt brief ...
# Name: content, Length: 9900, dtype: object

# %%
#separating the data and label
X = news_dataset['content'].values
Y = news_dataset['label'].values

# %%
print(X)
# Out:
# ['top trump surrog brutal stab back pathet video look though republican presidenti candid donald trump lose support even within rank know thing get bad even top surrog start turn exactli happen fox news newt gingrich call trump pathet gingrich know trump need keep focu hillari clinton even remot want chanc defeat howev trump hurt feel mani republican support sexual assault women turn includ hous speaker paul ryan r wi made trump lash parti gingrich said fox news look first let say trump admir tri help much big trump littl trump littl trump frankli pathet mean mad get phone call trump refer fact paul ryan call congratul debat probabl win despit trump ego tell gingrich also ad donald trump one oppon name hillari clinton name paul ryan anybodi els trump seem realiz person mad truli worst enemi ultim lead defeat one blame watch via politico featur photo joe raedl getti imag'
#  'u conserv leader optimist common ground healthcar washington reuter republican u hous repres could achiev common ground deal win support healthcar legisl thursday presid donald trump interven negoti conserv leader said wednesday yet optimist work around clock noon tomorrow go abl hope find common ground repres mark meadow chairman conserv hous freedom caucu told report meadow group oppos hous republican healthcar legisl threaten earlier day block passag thursday vote'
#  'trump propos u tax overhaul stir concern deficit washington reuter presid donald trump propos wednesday biggest u tax overhaul three decad call tax cut american prompt critic plan favor busi rich could add trillion dollar deficit propos drew swift skeptic respons senat bob corker lead republican fiscal hawk vow vote feder tax packag financ borrow money tell vote bill increas deficit period corker said tuesday would seek elect told report trump said tax plan aim help work peopl creat job make tax code simpler fairer face uphil battl u congress trump republican parti divid democrat hostil plan would lower corpor small busi incom tax rate reduc top incom tax rate high earn american individu scrap popular tax break includ one benefit peopl high tax state domin democrat forg month talk among trump aid top congression republican plan contain detail pay tax cut without expand budget deficit ad nation trillion nation debt plan still must turn legisl expect congress make progress fiscal budget perhap octob must debat republican led congression tax write committe analyst skeptic congress could approv tax bill year republican hope achiev enter next year congression elect campaign least one legisl achiev show financi market ralli plan unveil event long anticip trader bet stock would benefit faster econom growth inflat event indianapoli trump call plan largest tax cut u histori want tax reform pro growth pro job pro worker pro famili ye tax reform pro american said real estat mogul turn politician promis big tax cut candid told report person would gain financi propos think littl benefit peopl wealth said trump unlik mani white hous predecessor refus make public tax return republican produc major legisl success sinc trump took offic januari even though control white hous chamber congress top legisl prioriti overhaul u healthcar system collaps senat tuesday comprehens rewrit u tax code elud previou presid congress decad last one pass republican presid ronald reagan trump plan fall short sweep bipartisan packag craft reagan congression democrat analyst said white hous said propos typic middl class famili would less incom subject feder tax trump said first earn individu first marri coupl would tax free plan would lower top individu tax rate paid nation top earner percent percent would lower top corpor incom tax rate percent current percent exist rate high global mani u base multin pay much less headlin rate abund loophol tax break trump appeal democrat back plan although consult draft republican hold thin senat major may need democrat support win passag democrat said plan would expand feder deficit order deliv tax cut wealthi american rather middl class famili trump republican say tri help framework middl class trump tower middl class hous said senat ron wyden top democrat tax law write senat financ committe republican kevin bradi chairman tax write hous repres way mean committe said expect tax legisl pass end year committe respons feder budget washington base polici group estim wednesday plan contain trillion total tax cut decad would net cost trillion analyst warn huge tax cut would balloon deficit econom growth project republican offset cost fail materi amid rise interest rate pass rate plan would set new percent tax rate pass busi usual small privat enterpris partnership sole proprietorship repres percent u busi current law profit compani pass directli owner tax person incom often top percent individu incom rate cut percent could mean big tax save small busi owner also vulner abus individu compani analyst said republican propos elimin tax deduct target popular one mortgag interest charit give call scrap one state local tax payment could especi hurt peopl high tax state like california new york step simplifi tax return plan would shrink current seven tax bracket three percent percent percent would rais bottom tax rate low earn american percent percent analyst said part plan would still mean net tax cut'
#  ...
#  'trump lawyer say judg lack jurisdict defam lawsuit new york reuter u presid donald trump lawyer told new york state judg tuesday u constitut jurisdict presid therefor urg dismiss defam lawsuit woman accus trump sexual harass lawsuit summer zervo former contest trump realiti show apprentic contend trump denial accus amount fals defamatori statement brand liar trump lawsuit said harm busi trump lawyer led marc kasowitz said constitut supremaci claus prevent judg let zervo lawsuit proceed state court hour long hear held new york state suprem court manhattan zervo lawyer respond legal preced prevent state court rule conduct presid outsid offici duti motion today noth put anyon law kasowitz told justic jennif schecter supremaci claus said state court may exercis jurisdict presid unit state offic schecter occasion stop kasowitz ask clarifi view jurisdict ask matter would direct presid offici duti potenti rule whether comment candid defam zervo kasowitz said made differ mean presid hale court presid hale court innumer oblig flow said say would amount inappropri control presid mariann wang lead lawyer zervo argu case hold feder offici cannot held account state court trump lawyer disput wang acknowledg presid hold uniqu posit note even presid downtim could exampl meet trump one weekend visit mar lago resort florida record video deposit suggest judg said would rule later trump lawyer said court file zervo make fals self contradictori polit motiv accus presid remark non action fieri rhetor zervo accus trump grope meet file lawsuit januari three day trump inaugur march subpoena trump presidenti campaign document concern similar alleg trump said accus zervo women last year accus sexual harass fals case went ahead could lead trump compel hand document campaign relat accus sexual improprieti made zervo lawyer includ gloria allr cite u suprem court rule clinton v jone allow former arkansa state employe paula jone sexual harass lawsuit bill clinton proceed still u presid decis led clinton impeach lie oath sexual relationship anoth woman monica lewinski trump lawyer said clinton v jone appli lawsuit feder court state court zervo met trump becom contest nbc apprentic accus trump kiss new york offic later grope hotel beverley hill met possibl job one sever women made accus trump emerg last year convers caught open microphon spoke vulgar term tri sex women trump said comment amount locker room banter campaign issu statement apolog anyon offend sinc lawsuit file numer accus sexual misconduct made power men polit media entertain'
#  'watch right wing pastor fals credit trump save auto industri rememb time donald trump rode white hors person save auto industri yeah neither one support think actual happen interview cnn trump favorit pastor darrel scott stun former detroit mayor denni archer new day host alisyn camerota make exact claim trash michigan citi hellhol republican nomine fix detroit bad shape scott said bad shape econom bad shape far crime concern candid say want improv condit citi econom want improv condit citi far crime concern turn deaf ear whoever archer took umbrag scott character citi warn voter scrutin candid make promis especi sinc trump give damn detroit poll number implod camerota ask scott continu gave trump credit someth presid bush presid obama respect someon say go put posit help detroit area need help scott went bail auto industri ye scott realli claim trump save auto industri height great recess cours record crystal clear presid bush sign first bailout chrysler gener motor presid obama took offic next year even help american auto industri stay aliv continu compet foreign automak auto industri fulli recov countri donald trump absolut noth someth scott realiz moment later clumsili attempt correct mean uh bail auto industri scott embarrassingli admit say work relationship auto industri order stimul american auto industri video via twitter heat debat donald trump outreach black voter http co sdqciimnc new day newday septemb trump support humili nation televis get fact complet wrong least scott decenc correct time featur imag getti imag'
#  'sean spicer hilari brand chickensh bolt brief tweet video oh mr spicey favorit press secretari love hate gymnast around donald trump antic gaff along alreadi stuff legend good way make relationship press acrimoni may well today turn chickenshit tuck tail leg ran away press brief leav white hous press corp absolut stun cri sean hey sean seeeeeean ah come sean walk away among loud disappoint protest come press corp undoubtedli squillion uncomfort question watch presssec liter fled press question today pic twitter com uiapibn american bridg american bridg may near end video hear someon say realli ye realli appar peopl twitter go spicey coward gleeful abandon american bridg presssec live feed sean spicer run wh pic twitter com wt j q dian dian may american bridg presssec pic twitter com pqz w whl ja barteej may american bridg glasgowdick presssec presssec quick press run hide pic twitter com jib yrzb sean callaghan keanespirit may american bridg presssec moment pic twitter com u xzjwewlf judg steve reinhold galileo may american bridg wycam presssec mayb spicey go potti pic twitter com keshwdnysm ny justic seeker nyjusticeseek may footag sean spicer today presser pic twitter com bnvx cma tynisa walker kalarigamerch may american bridg presssec pic twitter com lcljndpgbt l j viewfrom thflr may american bridg presssec damn sean least littl style pic twitter com ytb het z bob parker bobusparkorum may american bridg marengel presssec put pass seanspic smh pic twitter com k jcnqkgl r g lastbreath may american bridg presssec pic twitter com dmtkni w allbiz ternivalentin may american bridg presssec coward die thousand death pic twitter com x hcvrpzkn erin larkin foster larkster erin may live look sean spicer ghost wh press pic twitter com w vmc ef g andi zeisler andizeisl may jaketurx childish natur administr never ceas amaz honestli wish would stop pic twitter com z ucwa aaj actindivis actindivis may scaredi spice presssec much coward face free press rep white hous press brief maddow spicer daysofsham pic twitter com xntmw xyeq daniel quinn mightyquinnusa may actual pic sean spicer flee press brief today pic twitter com nnoganwc w prubjot kaur prubjotkaur may sean spicer flee wh press corp like pic twitter com jn dfn jenn lerner jenniferlern may poor seanspic huge pussi realdonaldtrump go grab day long http co pj ej tmw pretti hat machin prettyhatmech may rush sean spicer leav wh press brief without field question http co u rd b cz american girl aiiamericangiri may sean spicer leav press confer shock look put kid bed everynight pic twitter com bhwajhoygw lulu chatter luluchatt may sean spicer leav white hous brief without take question press spicer pic twitter com afi emgiqf mangoman mangoman may actual footag sean spicer today press brief pic twitter com xhzdkhtkm slickvand may media unhappi develop realli afraid say mother jone call soundtrack presid hill said spicer stun report market watch note press left volley question toward empti podium sean sean hey sean come putin call sean caption photo read like conclud root take perhap spicer need time compos altern fact knew present salmon skin stalin said tuesday new budget enough money payment wall sen patrick leahi vt senat appropri committe rank democrat member respond twitter clear fund bill kind payment construct new border wall mayb spicer nervou respond trump tweet earlier tuesday insist govern need good shutdown blindli loyal trump support say own press unfortun narr spicey answer question necessarili like want answer part parcel job get run away want talk without explain time get cut short someth els realli spicer got own featur imag via screen captur embed video']

# %%
print(Y)
# Out:
# ['Fake' 'Real' 'Real' ... 'Real' 'Fake' 'Fake']

# %%
Y.shape
# Out:
# (9900,)

# %%
# converting the textual data to numerical data
vectorizer = TfidfVectorizer()
vectorizer.fit(X)

X = vectorizer.transform(X)

# %%
print(X)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 1550030 stored elements and shape (9900, 40295)>
#   Coords	Values
#   (0, 287)	0.04778447355034268
#   (0, 363)	0.09682298048854796
#   (0, 972)	0.03143972892540736
#   (0, 1448)	0.08345934109394892
#   (0, 1856)	0.07286371750620677
#   (0, 2257)	0.039527598617236225
#   (0, 2297)	0.05966411102820767
#   (0, 3213)	0.056383490883613656
#   (0, 3432)	0.06506791054573881
#   (0, 4362)	0.08391465433975229
#   (0, 4826)	0.10289134738400817
#   (0, 4910)	0.056223303571082184
#   (0, 5468)	0.06871518325327437
#   (0, 6151)	0.09885764047479048
#   (0, 6687)	0.09815225049215494
#   (0, 8036)	0.06544078756938368
#   (0, 8151)	0.1531963802975418
#   (0, 8470)	0.05695591125723686
#   (0, 9163)	0.04559368638204754
#   (0, 10010)	0.08854881843203868
#   (0, 10221)	0.0668700967402666
#   (0, 10404)	0.08237005776544144
#   (0, 10837)	0.10579196794059839
#   (0, 10914)	0.06618300605342758
#   (0, 11142)	0.045310736697916625
#   :	:
#   (9899, 37855)	0.03572656618752602
#   (9899, 37948)	0.030637341126977847
#   (9899, 38074)	0.01843132437696852
#   (9899, 38075)	0.026408291274161413
#   (9899, 38081)	0.02958115359928728
#   (9899, 38114)	0.017680334163222487
#   (9899, 38191)	0.022409581691389645
#   (9899, 38226)	0.009347660767793309
#   (9899, 38394)	0.009773968094793025
#   (9899, 38485)	0.09210446256606243
#   (9899, 38569)	0.02419548741632187
#   (9899, 38601)	0.039537077197067096
#   (9899, 38811)	0.018630976792850668
#   (9899, 38836)	0.03600337060232662
#   (9899, 39034)	0.00636896714524179
#   (9899, 39131)	0.03665453689530752
#   (9899, 39203)	0.039537077197067096
#   (9899, 39298)	0.039537077197067096
#   (9899, 39358)	0.039537077197067096
#   (9899, 39452)	0.039537077197067096
#   (9899, 39459)	0.039537077197067096
#   (9899, 39547)	0.016348786944778572
#   (9899, 39779)	0.039537077197067096
#   (9899, 39785)	0.039537077197067096
#   (9899, 40002)	0.0378508992137203

# %% [markdown]
# Splitting the dataset to training & test data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, stratify=Y, random_state=2)

# %% [markdown]
# Training the Model: Logistic Regression

# %%
model = LogisticRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# Evaluation

# %% [markdown]
# accuracy score

# %%
# accuracy score on the training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy score of the training data : ', training_data_accuracy)
# Out:
# Accuracy score of the training data :  0.9962121212121212

# %%
# accuracy score on the test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score of the test data : ', test_data_accuracy)
# Out:
# Accuracy score of the test data :  0.9868686868686869

# %% [markdown]
# Making a Predictive System

# %%
X_new = X_test[3] # L'article de test à prédire

prediction = model.predict(X_new)
print(prediction)

# Correction : Comparer avec les chaînes de caractères 'Real' et 'Fake'
if (prediction[0]=='Real'):
  print('The news is Real')
else:
  print('The news is Fake')
# Out:
# ['Real']
# The news is Real

# %%
print(Y_test[3])
# Out:
# Real
